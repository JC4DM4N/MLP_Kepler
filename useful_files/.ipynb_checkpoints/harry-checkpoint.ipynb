# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from os import listdir
pwd = '/disk1/hrb/MLP_Kepler/'

# %%
from funcs.cleaning import clean
from astropy.table import Table

# %%
koi = pd.read_csv('../KOI.csv', index_col='kepid').sort_index()

# %%
a = clean(koi.index.values[0], koi, 1)

# %%
a.clean_arrays()
# Out:
# no. datapoints prior to cleaning: 4354
# no. datapoints after cleaning: 4070

# %%
a.plot()

# %%
a.remove_stellar_activity()
# Out:
# spline-fit converged after 2 iterations.

# %%
a.fold_data()

# %%
from keras.datasets import imdb
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence
# fix random seed for reproducibility
np.random.seed(7)

# %%
# do some machine learning
