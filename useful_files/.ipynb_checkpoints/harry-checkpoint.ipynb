# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from os import listdir
fnames = sorted(listdir('../fits/slc/'))
fnames = [fname[14:31] for fname in fnames if (fname[4:13] == '{:09d}'.format(system_id))]

# %%
fnames
# Out:
# []

# %%
data = Table.read('../fits/slc/kplr{:09d}-{}.fits'.format(system_id, fnames[0]))['TIME','PDCSAP_FLUX','PDCSAP_FLUX_ERR']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-b353f46b2a49> in <module>
# ----> 1 data = Table.read('../fits/slc/kplr{:09d}-{}.fits'.format(system_id, fnames[0]))['TIME','PDCSAP_FLUX','PDCSAP_FLUX_ERR']
#
# IndexError: list index out of range

# %%
from funcs.cleaning import clean
from astropy.table import Table

# %%
koi = pd.read_csv('../KOI.csv', index_col='kepid').sort_index()

# %%
system_id = koi.index.values[0]

# %%
a = clean(system_id, koi, None)
# Out:
# /disk1/hrb/MLP_Kepler/useful_files/funcs/cleaning.py:53: RuntimeWarning: Mean of empty slice.
#   f -= f.mean() +1e4
# /disk1/hrb/anaconda3/envs/astroconda/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
a.clean_arrays()
a.plot()
# Out:
# no. datapoints prior to cleaning: 804720
# no. datapoints after cleaning: 51069

# %%
a.remove_stellar_activity()
# Out:
# spline-fit converged after 18 iterations.

# %%
from keras.datasets import imdb
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence
# fix random seed for reproducibility
np.random.seed(7)

# %%
# do some machine learning
